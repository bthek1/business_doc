# %% [raw]
# ---
# output-file: companies.html
# title: Companies
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## For jobs

# %% [markdown]
# ## Investment firms

# %% [markdown]
# - Main sequence - CSIRO backer
# - Y combinator

# %% [markdown]
# ## Competition

# %% [markdown]
# - luceo
# - redback
# -
